# %% [markdown]
# ### Read data from files

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
from brokenaxes import brokenaxes
import pprint

pd.set_option("display.max_rows", None, "display.max_columns", None)
dict = {}
prec_dict = {}
approximation = {}
precision = {}
definitive_unrel = {}
definitive_unavail = {}
precisiontostate = {}
exploring_iteration = False
excel_sheet = pd.read_csv("FIG2STORM_API_results_EXPORT_CSV.csv", index_col=0)
definitive_unrel['Model_name'] = []
definitive_unavail['Model_name'] = []
definitive_unrel['time_unrel'] = []
definitive_unavail['time_unavail'] = []
definitive_unrel['states_unrel'] = []
definitive_unrel['transitions_unrel'] = []
definitive_unavail['states_unavail'] = []
definitive_unavail['transitions_unavail'] = []

definitive_unrel['unrel'] = []
definitive_unavail['unavail'] = []

dict['iteration'] = []
dict['states'] = []
dict['transitions'] = []
dict['lower_bound'] = []
dict['upper_bound'] = []
dict['computation_time'] = []
prec_dict['precision'] = []
prec_dict['states'] = []
prec_dict['transitions'] = []
prec_dict['lower_bound'] = []
prec_dict['upper_bound'] = []
prec_dict['computation_time'] = []
test_type = 'null'
approx_type = 'null'
model_name = ''
print_now = False

with PdfPages('result.pdf') as pdf:
    with open("result_NPPs.txt", 'r') as file:
        lines = file.readlines()
        for no, line in enumerate(lines):
            match = re.search(r"\[ RUN      \] (.*)\.(.*)", line)
            if match:
                if approx_type != 'null':
                    model_name = match.group(2) + '_'+approx_type
                else:
                    model_name = match.group(2)

            match = re.search(r"(.*)\(anonymous namespace\)::(.*)", line)
            # if match:
            #     approx_type = match.group(2)
            #     continue
            match = re.search(r'Start of Definite Tests', line)
            if match:
                test_type = 'definite'
                continue
            match = re.search(r'start of Approximation test', line)
            if match:
                test_type = 'approximation'
            match = re.search(r'start of Precision graph test', line)
            if match:
                test_type = 'precision'
            if test_type == 'definite':
                match = re.search(r'The result is \.\.', line)
                if match:
                    if lines[no - 15].strip().split("Pmin=? [")[1][:8] == 'true U<=':
                        definitive_unrel['Model_name'].append(model_name)
                        definitive_unrel['time_unrel'].append(float(lines[no + 6].split()[1][:-1]))
                        definitive_unrel['unrel'].append(float(lines[no + 7].strip().split("[")[1][:-1]))
                        definitive_unrel['states_unrel'].append(int(lines[no - 11].strip().split()[1]))
                        definitive_unrel['transitions_unrel'].append(int(lines[no - 10].strip().split()[1]))
                    if lines[no - 15].strip().split("Pmin=? [")[1][:7] == 'true U[':
                        definitive_unavail['Model_name'].append(model_name)
                        definitive_unavail['time_unavail'].append(float(lines[no + 6].split()[1][:-1]))
                        definitive_unavail['unavail'].append(float(lines[no + 7].strip().split("[")[1][:-1]))
                        definitive_unavail['states_unavail'].append(int(lines[no - 11].strip().split()[1]))
                        definitive_unavail['transitions_unavail'].append(int(lines[no - 10].strip().split()[1]))
            elif test_type == 'approximation':
                match = re.search(r'Model in iteration (.*):',line)
                if match:
                    dict['iteration'].append(match.group(1))
                    dict['states'].append(int(lines[no + 3].strip().split()[1]))
                    dict['transitions'].append(int(lines[no + 4].strip().split()[1]))
                    continue
                match = re.search(r"Result after iteration (.*): \((.*), (.*)\)", line)
                if match:
                    dict['lower_bound'].append(match.group(2).strip())
                    dict['upper_bound'].append(match.group(3).strip())
                    dict['computation_time'].append(float(lines[no + 6].split()[1][:-1]))
                    continue
                match = re.search(r'The result is \.\.', line)
                if match:
                    if model_name in approximation:
                        approximation[model_name+'_unavail'] = pd.DataFrame(dict)
                    else:
                        approximation[model_name] = pd.DataFrame(dict)
                    dict.clear()
                    dict['iteration'] = []
                    dict['states'] = []
                    dict['computation_time'] = []
                    dict['transitions'] = []
                    dict['lower_bound'] = []
                    dict['upper_bound'] = []
                    continue
            elif test_type == 'precision':
                match = re.search(r'The result for the precision: (.*)',line)
                if match:
                    prec_dict['precision'].append(match.group(1))
                    prec_dict['states'].append(int(lines[no + 3].strip().split()[1]))
                    prec_dict['transitions'].append(int(lines[no + 4].strip().split()[1]))
                    prec_dict['computation_time'].append(float(lines[no + 19].split()[1][:-1]))
                    prec_dict['lower_bound'].append(lines[no+20].strip().split()[1][2:-1])
                    prec_dict['upper_bound'].append(lines[no+20].strip().split()[2][:-2])
                    continue
                match = re.search(r"Lower limit: (.*)  Nominal Value: (.*) Upper limit:(.*)", line)
                if match:
                    if model_name in precision:
                        precision[model_name+'_unavail'] = pd.DataFrame(prec_dict)
                    else:
                        precision[model_name] = pd.DataFrame(prec_dict)
                    prec_dict.clear()
                    prec_dict['precision'] = []
                    prec_dict['states'] = []
                    prec_dict['transitions'] = []
                    prec_dict['computation_time'] = []
                    prec_dict['lower_bound'] = []
                    prec_dict['upper_bound'] = []
            else:
                    continue
        frame_definitive_unrel = pd.DataFrame(definitive_unrel)
        # frame_definitive_unrel = frame_definitive_unrel.set_index('Model_name')
        frame_definitive_unavail = pd.DataFrame(definitive_unavail)
        # frame_definitive_unavail = frame_definitive_unavail.set_index('Model_name')
        print('definite', frame_definitive_unrel)
        print('precision',precision)
        print('approximation',approximation)
# Out:
# definite Empty DataFrame
# Columns: [Model_name, time_unrel, states_unrel, transitions_unrel, unrel]
# Index: []
# precision {'FigaroProgram_NPPS_Trim_article_No_repair':    precision    states  transitions lower_bound upper_bound  computation_time
# 0          1        79          155           0    0.549521             0.066
# 1        0.5       738         1452    0.037902    0.517459             0.432
# 2        0.2      3657         7289    0.245163    0.428693             2.219
# 3        0.1     10525        21415    0.300392     0.38723             6.391
# 4       0.05     30758        63553    0.327501    0.375647            19.189
# 5       0.02    149487       312718    0.347737    0.366334            95.605
# 6       0.01    383670       806260    0.354089    0.363131           257.231
# 7      0.005    903375      1898016    0.357347     0.36168           629.147
# 8      0.002   3130826      6605792    0.359298    0.360857          2210.522
# 9      0.001   6964258     14721249    0.359875    0.360614          4973.770
# 10    0.0005  10267027     21742141    0.360045    0.360539          7388.005
# 11    0.0002  31709439     67312519      0.3603     0.36044         23362.068
# 12    0.0001  45466739     96583184    0.360337    0.360427         34921.748, 'FigaroProgram_NPPS_Trim_article_repair':    precision   states  transitions  computation_time  lower_bound  upper_bound
# 0          1       79          156             0.068            0     0.557781
# 1        0.5      149          296             0.109            0     0.452745
# 2        0.2      557         1117             0.341            0     0.187198
# 3        0.1     1365         2868             1.018            0    0.0553538
# 4       0.05     1797         3841             1.406            0    0.0321776
# 5       0.02     2425         5176             2.145            0    0.0167767
# 6       0.01     5169        11054             4.489            0   0.00615841
# 7      0.005     7093        15207             6.180            0    0.0034775
# 8      0.002    11535        24955            10.392            0   0.00165996
# 9      0.001    17317        37699            16.288  1.34584e-05  0.000731517
# 10    0.0005    27380        59153            26.469  2.27329e-05  0.000393884
# 11    0.0002    44841        97784            43.882  2.81894e-05  0.000193653
# 12    0.0001    75233       167629            74.278  3.31513e-05   9.6764e-05
# 13     5e-05    96480       215936            96.102  3.43053e-05  7.38095e-05
# 14     2e-05   145373       328380           152.833  3.57107e-05  5.12275e-05
# 15     1e-05   216855       494185           238.242  3.63967e-05  4.29513e-05
# 16     5e-06   262395       602048           296.365  3.65684e-05  4.07741e-05
# 17     2e-06   394943       919302           455.364   3.6765e-05  3.85459e-05
# 18     1e-06   578802      1361629           688.732   3.6877e-05  3.76371e-05
# 19     5e-07   859058      2041451          1043.119  3.69129e-05  3.72012e-05
# 20     2e-07  1022163      2442322          1270.916   3.6923e-05  3.70947e-05
# 21     1e-07  1487633      3598084          1884.895  3.69325e-05  3.70027e-05
# 22     5e-08  1802379      4389345          2305.781  3.69349e-05  3.69784e-05
# 23     2e-08  2677158      6605499          3478.601  3.69373e-05  3.69559e-05}
# approximation {'FigaroProgram_NPPS_Trim_article_No_repair':    iteration    states  transitions   lower_bound   upper_bound  \
# 0          1        79           78             0  0.5495213455
# 1          2        79           78             0  0.5495213455
# 2          3       153          301             0  0.5472505367
# 3          4       334          658             0  0.5455689404
# 4          5       738         1452   0.037901956  0.5174586753
# 5          6      1154         2274  0.1258826808  0.4665932549
# 6          7      1936         3818  0.1784227126  0.4604865058
# 7          8      3657         7289  0.2451630071  0.4286925457
# 8          9      6559        13260  0.2759852373  0.3976228664
# 9         10     10525        21415  0.3003916031  0.3872299853
# 10        11     18177        37189  0.3165067369  0.3806070838
# 11        12     30758        63553  0.3275013054  0.3756472097
# 12        13     53002       109945   0.335331834  0.3715285347
# 13        14     90521       189017  0.3428077404  0.3685569874
# 14        15    149487       312718  0.3477373415  0.3663338037
# 15        16    245117       513757  0.3518278315  0.3643970264
# 16        17    383670       806260  0.3540888416  0.3631313457
# 17        18    595200      1249930  0.3559073889  0.3622240434
# 18        19    903375      1898016   0.357347331  0.3616800494
# 19        20   1382058      2906757  0.3581963406  0.3613157732
# 20        21   2094555      4413769   0.358834126  0.3610450744
# 21        22   3130826      6605792  0.3592977647  0.3608566515
# 22        23   4680699      9880089  0.3596497838  0.3607131854
# 23        24   6964258     14721249  0.3598747255  0.3606136253
# 24        25  10267027     21742141  0.3600450515    0.36053891
# 25        26  15072463     31944488  0.3601622177  0.3604907098
# 26        27  21945847     46547202  0.3602427963  0.3604603717
# 27        28  31709439     67312519  0.3602997963   0.360440196
# 28        29  45466739     96583184  0.3603370737  0.3604269889
#
#     computation_time
# 0              0.059
# 1              0.069
# 2              0.118
# 3              0.223
# 4              0.452
# 5              0.737
# 6              1.250
# 7              2.228
# 8              3.934
# 9              6.460
# 10            11.133
# 11            19.059
# 12            32.924
# 13            56.954
# 14            95.492
# 15           159.660
# 16           256.034
# 17           403.449
# 18           622.173
# 19           955.973
# 20          1459.111
# 21          2197.360
# 22          3304.895
# 23          4945.486
# 24          7338.592
# 25         10841.265
# 26         15887.972
# 27         23160.630
# 28         33529.279  , 'FigaroProgram_NPPS_Trim_article_repair':    iteration  states  computation_time  transitions      lower_bound  \
# 0          1      79             0.040           79                0
# 1          2      79             0.049           79                0
# 2          3      79             0.059           79                0
# 3          4     149             0.099          296                0
# 4          5     184             0.131          366                0
# 5          6     557             0.319         1117                0
# 6          7     594             0.399         1192                0
# 7          8     906             0.609         1848                0
# 8          9    1365             0.944         2868                0
# 9         10    1797             1.318         3841                0
# 10        11    2085             1.658         4476                0
# 11        12    2425             2.045         5176                0
# 12        13    2824             2.496         5992                0
# 13        14    3477             3.136         7382                0
# 14        15    5169             4.292        11054                0
# 15        16    7093             5.788        15207                0
# 16        17    8366             7.239        17976                0
# 17        18   11535             9.759        24955                0
# 18        19   14260            12.497        31050  6.690181292e-06
# 19        20   17317            15.663        37699  1.345838802e-05
# 20        21   22624            20.208        48981  1.977537081e-05
# 21        22   27380            25.283        59153  2.273291101e-05
# 22        23   35700            32.900        77436  2.632977636e-05
# 23        24   44841            42.166        97784  2.818939304e-05
# 24        25   57182            54.684       126107  3.091465208e-05
# 25        26   75233            71.849       167629  3.315128056e-05
# 26        27   96480            92.821       215936  3.430528486e-05
# 27        28  121709           118.860       273501  3.527896384e-05
# 28        29  145373           148.005       328380  3.571071359e-05
# 29        30  175619           183.946       398652   3.61187805e-05
# 30        31  216855           230.379       494185  3.639672796e-05
# 31        32  262395           285.610       602048  3.656840839e-05
# 32        33  324778           355.762       749393  3.668919447e-05
# 33        34  394943           440.186       919302  3.676497482e-05
# 34        35  483472           543.623      1130414  3.683842728e-05
# 35        36  578802           665.686      1361629  3.687699881e-05
#
#         upper_bound
# 0      0.5577810234
# 1      0.5577810234
# 2      0.5577810234
# 3      0.4527446299
# 4      0.4304314403
# 5      0.1871981872
# 6      0.1727382853
# 7      0.1170828506
# 8     0.05535375988
# 9     0.03217763758
# 10    0.02225345194
# 11    0.01677666603
# 12    0.01297002049
# 13    0.01002597326
# 14    0.00615841454
# 15   0.003477496165
# 16   0.002557379283
# 17   0.001659964611
# 18   0.001111018331
# 19  0.0007315168452
# 20  0.0005215941258
# 21  0.0003938841765
# 22  0.0002828011697
# 23  0.0001936527834
# 24  0.0001348495481
# 25   9.67640358e-05
# 26  7.380946484e-05
# 27  5.918708099e-05
# 28  5.122750832e-05
# 29  4.628129531e-05
# 30  4.295125626e-05
# 31   4.07740651e-05
# 32  3.937794563e-05
# 33  3.854586392e-05
# 34  3.800567438e-05
# 35  3.763714809e-05  }

# %% [markdown]
# ### Generate first graph

# %%
# definitive =frame_definitive_unrel.loc[frame_definitive_unrel['Model_name'] == 'FigaroProgram_sf3_2_trim_no_repair']
# definitive1 = frame_definitive_unrel.loc[1]
# definitive = frame_definitive_unrel.loc[0]
# print(definitive['Model_name'])
fig, ax = plt.subplots()
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=6)
plt.rc('legend',fontsize=14)
plt.xlabel('xlabel', fontsize=12)
plt.ylabel('ylabel', fontsize=12)
# font = {'family': 'normal',
#         'weight': 'bold',
#         'size': 6}
plt.rcParams.update({'font.size': 12})
# fig.suptitle(definitive['Model_name']+'_unreliability')
# fig.tight_layout(pad=6.0)
one_frame = approximation['FigaroProgram_NPPS_Trim_article_No_repair']
one_frame_1 = approximation['FigaroProgram_NPPS_Trim_article_repair']

ax.plot(one_frame['iteration'].astype(int), one_frame['states']/float(one_frame['states'][-1:])*100,'-b',label='States: repairable', alpha=0.5)
ax.plot(one_frame_1['iteration'].astype(int), one_frame_1['states']/float(one_frame_1['states'][-1:])*100,'--b',label='States: non-repairable', alpha=0.5)

leg =  ax.legend(loc=2)#,fancybox=True, framealpha=0.0)
# ax.set_title('Iteration vs explored states')
ax.set_xlabel('# Iterations')
ax.set_ylabel('% of total states', color="blue")
ax.set_yticks(np.arange(0, 110, 20))

ax2 =  ax.twinx()
ax2.plot(one_frame['iteration'].astype(int), one_frame['computation_time'].astype(float)/float(one_frame['computation_time'][-1:].astype(float))* 100, lw=2, color="red", label='Time: repairable', alpha=0.5)
ax2.plot(one_frame_1['iteration'].astype(int), one_frame_1['computation_time'].astype(float)/float(one_frame_1['computation_time'][-1:].astype(float))* 100, lw=2, color="red", linestyle='--',label='Time: non-repairable', alpha=0.5)
ax2.locator_params(axis='y', nbins=5)
leg = ax2.legend(loc=2,bbox_to_anchor=(0,0.75))#,fancybox=True, framealpha=0.0)
ax2.set_yticks(np.arange(0,110,20))
ax2.set_ylabel(r"% of total computation time", color="red")
for label in ax2.get_yticklabels():
    label.set_color("red")
for label in ax.get_yticklabels():
    label.set_color("blue")
fig.tight_layout()
ax.set_xticks(np.arange(0, 36, 5))
fig.savefig('NPPS_iterationvsstatespace.pdf')

# %% [markdown]
# ### Generate second graph

# %%
## definitive =frame_definitive_unrel.loc[frame_definitive_unrel['Model_name'] == 'FigaroProgram_sf3_2_trim_no_repair']
# definitive1 = frame_definitive_unrel.loc[1]
# definitive = frame_definitive_unrel.loc[0]
# print(definitive['Model_name'])
fig, ax = plt.subplots()
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=5)
plt.rc('legend',fontsize=12)
plt.xlabel('xlabel', fontsize=12)
plt.ylabel('ylabel', fontsize=12)
# font = {'family': 'normal',
#         'weight': 'bold',
#         'size': 12}
plt.rcParams.update({'font.size': 12})
# fig.suptitle(definitive['Model_name']+'_unreliability')
# fig.tight_layout(pad=6.0)
one_frame = precision['FigaroProgram_NPPS_Trim_article_No_repair']
one_frame_1 = precision['FigaroProgram_NPPS_Trim_article_repair']

# ax.set_title('Threshold vs explored states')
ax.set_xlabel('Threshold')
ax.set_ylabel('% of total states',color="blue")
ax.set_yticks(np.arange(0, 110, 20))
ax.set_xscale('log')
ax.plot(one_frame['precision'].astype(float), one_frame['states'].astype(int) / (
    int(one_frame['states'][-1:].astype(int))) * 100,  '-b', label='States: non-rep', alpha=0.5)
ax.plot(one_frame_1['precision'].astype(float), one_frame_1['states'].astype(int) / (
    int(one_frame_1['states'][-1:].astype(int))) * 100,  '--b', label='States: repairable',alpha=0.55)
ax.invert_xaxis()
ax2 = ax.twinx()
leg = ax.legend()#fancybox=True, framealpha=0.0)
ax2.plot(one_frame['precision'].astype(float), one_frame['computation_time'].astype(float) / float(
    one_frame['computation_time'][-1:].astype(float)) * 100,  color="red", linestyle='-', label='Time: non-rep.')
ax2.plot(one_frame_1['precision'].astype(float), one_frame_1['computation_time'].astype(float) / float(
    one_frame_1['computation_time'][-1:].astype(float)) * 100,  color="red", linestyle='--',label='Time: repairable', alpha=0.55)
ax2.locator_params(axis='y', nbins=5)
ax2.set_yticks(np.arange(0, 120, 20))
ax2.set_ylabel(r"% of total computation time", color="red",zorder=2)
ax2.legend(loc=3, bbox_to_anchor=(0,0.55))#, fancybox=True, framealpha=0.0)
for label in ax2.get_yticklabels():
    label.set_color("red")
for label in ax.get_yticklabels():
    label.set_color("blue")
fig.tight_layout()
fig.savefig('NPPS_thresholdvsstatespace.pdf')

# %% [markdown]
# ### Generate thrid graph

# %%
# print(definitive['Model_name'])
fig, ax = plt.subplots()
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=6)
plt.rc('legend',fontsize=12)
plt.xlabel('xlabel', fontsize=12)
plt.ylabel('ylabel', fontsize=12)

font = {'family': 'normal',
        'weight': 'bold',
        'size': 12}
plt.rcParams.update({'font.size': 12})
# fig.suptitle(definitive['Model_name']+'_unreliability')
# fig.tight_layout(pad=6.0)
one_frame = approximation['FigaroProgram_NPPS_Trim_article_No_repair']
one_frame_1 = approximation['FigaroProgram_NPPS_Trim_article_repair']
nonrep_unrel = (float(one_frame['upper_bound'][-1:].astype(float)) + float(one_frame['lower_bound'][-1:].astype(float)))*0.5
rep_unrel = (float(one_frame_1['upper_bound'][-1:].astype(float)) + float(one_frame_1['lower_bound'][-1:].astype(float)))*0.5

ax.semilogy(one_frame['iteration'].astype(int), abs(
                nonrep_unrel - one_frame['upper_bound'].astype(
            float)) / nonrep_unrel, '-k', label='Upper-bound: non-repairable')

ax.semilogy(one_frame['iteration'].astype(int),
              abs(nonrep_unrel - one_frame['lower_bound'].astype(float))/
              nonrep_unrel, '-b', label='Lower-bound: non-repairable')

ax.semilogy(one_frame_1['iteration'].astype(int), abs(
                 rep_unrel - one_frame_1['upper_bound'].astype(
             float)) / rep_unrel, '--k', label='Upper-bound: repairable')

ax.semilogy(one_frame_1['iteration'].astype(int),
               abs((rep_unrel - one_frame_1['lower_bound'].astype(float))/
               rep_unrel), '--b', label='Lower-bound: repairable')

leg = ax.legend()#fancybox=True, framealpha=0.0)
# ax.set_title('Iteration vs abs. relative errors [threshold 1e-9]')
ax.set_xlabel('# Iterations')
ax.set_ylabel('log(|% relative error|)')

# secax = ax.secondary_xaxis('top')
# secax.set_xlabel('angle [rad]')
# secax.set_xticks(one_frame_1['iteration'].astype(int))
ax.set_xticks(np.arange(0, 36, 5))
fig.savefig('NPPS_upper_lower_limit.pdf')

# %% [markdown]
# ### Generate fourth graph

# %%
# definitive1 = frame_definitive_unrel.loc[1]
# definitive = frame_definitive_unrel.loc[0]
#print(definitive['Model_name'])
fig, ax = plt.subplots()
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=6)
plt.rc('legend',fontsize=12)
plt.xlabel('xlabel', fontsize=12)
plt.ylabel('ylabel', fontsize=12)
font = {'family': 'normal',
        'weight': 'bold',
        'size': 12}
plt.rcParams.update({'font.size': 12})
# fig.suptitle(definitive['Model_name']+'_unreliability')
# fig.tight_layout(pad=6.0)
one_frame = approximation['FigaroProgram_NPPS_Trim_article_No_repair']
one_frame_1 = approximation['FigaroProgram_NPPS_Trim_article_repair']
nonrep_unrel = (float(one_frame['upper_bound'][-1:].astype(float)) + float(one_frame['lower_bound'][-1:].astype(float)))*0.5
rep_unrel = (float(one_frame_1['upper_bound'][-1:].astype(float)) + float(one_frame_1['lower_bound'][-1:].astype(float)))*0.5

# one_frame = approximation[definitive['Model_name']]
# ax.plot(one_frame['iteration'].astype(int), definitive['unrel']*np.ones(len(one_frame['iteration'])),'-g',label='Definitive value', alpha=0.5)
mean_bound = 0.5 * (one_frame['upper_bound'].astype(float)  + one_frame['lower_bound'].astype(float))
# ax[0,0].plot(one_frame['iteration'].astype(int), mean_bound,'-b',label='mean')
ax.plot(one_frame['iteration'].astype(int),   (nonrep_unrel-one_frame['upper_bound'].astype(float))/nonrep_unrel, '-b', label='Upper-bound: non-rep.')
ax.plot(one_frame['iteration'].astype(int),   (nonrep_unrel-one_frame['lower_bound'].astype(float))/nonrep_unrel,'-k', label='Lower-bound: non-rep.')
ax.plot(one_frame_1['iteration'].astype(int),   (rep_unrel -one_frame_1['upper_bound'].astype(float))/rep_unrel, '--b', label='Upper-bound: rep.')
ax.plot(one_frame_1['iteration'].astype(int),   (rep_unrel -one_frame_1['lower_bound'].astype(float))/rep_unrel,'--k', label='Lower-bound: rep.')
leg = ax.legend(loc=2, bbox_to_anchor=(0.15,0.4))
ax.set_ylim(-1.1,1.1)
ax.set_xlabel('# Iterations')
ax.set_ylabel('% relative error')
ax.set_xticks(np.arange(0, 36, 5))        
fig.savefig('NPPS_bound_converge.pdf')
