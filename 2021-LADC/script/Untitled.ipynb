# %%
! python test.py
# Out:
# Adding (name, value) = (rateS2Z3_Electric_Wiring_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor1_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor2_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor3_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor4_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor5_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor6_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor7_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor8_Failure, 1e-05
# Adding (name, value) = (rateFire_Operator_NonAction_Failure, 1e-05
# Adding (name, value) = (rateFire_Information_Panel_WiringToSystem_Failure, 1e-05
# Adding (name, value) = (rateSwitch_Mechanism_Failed, 1e-05
# Adding (name, value) = (rateGrid_Power_Failure, 1e-05
# Adding (name, value) = (rateGenerator1_Failure, 1e-05
# Adding (name, value) = (rateFIP_UPS_Failure, 1e-05
# ...

# %%
generateResults(generated_drn_file, degraded_label, time_bound, drive_cycle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-50480c137e68> in <module>
# ----> 1 generateResults(generated_drn_file, degraded_label, time_bound, drive_cycle)
#
# NameError: name 'generateResults' is not defined

# %%
! python test.py
# Out:
# Adding (name, value) = (rateS2Z3_Electric_Wiring_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor1_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor2_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor3_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor4_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor5_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor6_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor7_Failure, 1e-05
# Adding (name, value) = (rateS2Z3_FireSensor8_Failure, 1e-05
# Adding (name, value) = (rateFire_Operator_NonAction_Failure, 1e-05
# Adding (name, value) = (rateFire_Information_Panel_WiringToSystem_Failure, 1e-05
# Adding (name, value) = (rateSwitch_Mechanism_Failed, 1e-05
# Adding (name, value) = (rateGrid_Power_Failure, 1e-05
# Adding (name, value) = (rateGenerator1_Failure, 1e-05
# Adding (name, value) = (rateFIP_UPS_Failure, 1e-05
# ...
